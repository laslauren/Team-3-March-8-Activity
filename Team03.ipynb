# %%
import torch
import torchvision
import matplotlib.pyplot as plt
import os
from os.path import join
from torch.utils.data import Dataset, DataLoader
from torchvision.io import read_image
import torchvision.transforms as transforms

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Running on {device}")
# Out:
# Running on cpu

# %%
mytrasnform = transforms.Compose([transforms.ToTensor()])

# %%
folder = "/Users/schama/Desktop/Mirror/00FSU/00CoursesSpring2023/DataHealth/ImageNet"

emnist = torchvision.datasets.CIFAR100(folder, download=True, transform=mytrasnform)
# Out:
# Files already downloaded and verified

# %%
dataloader = DataLoader(emnist, batch_size=4, shuffle=True)

# %%
def plot_batch_mnist(batch_imgs, batch_labels):
    batch_size = len(batch_imgs)
    fig, axs = plt.subplots(1, batch_size, figsize=(10,5))
    for i in range(batch_size):
        axs[i].imshow(batch_imgs[i,0,:,:])
        axs[i].set_title(f"Label {batch_labels[i]}")
    plt.show()

# %%
for c_batch in dataloader:
    x, y = c_batch
    plot_batch_mnist(x, y)
    break
